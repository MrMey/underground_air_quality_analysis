# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('all_data.csv')
# Out:
# c:\program files\python36\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#      co2  humi    no   no2   pm10  pm2.5 station  temp        date      time  \
# 0  403.0  51.2   NaN   NaN  295.0  118.0   auber  20.4  2013-01-01  10:00:00
# 1  403.0  51.2   NaN   NaN  295.0  118.0   auber  20.4  2013-01-01  10:00:00
# 2  403.0  51.2   NaN   NaN  295.0  118.0   auber  20.4  2013-01-01  10:00:00
# 3  767.0  46.4  99.0  54.0  362.0  110.0   auber  18.3  2013-01-15  10:00:00
# 4  767.0  46.4  99.0  54.0  362.0  110.0   auber  18.3  2013-01-15  10:00:00
#
#    precipitation  temp_min  temp_max ligne  stop_id
# 0            8.0       8.0       9.0     3      389
# 1            8.0       8.0       9.0     9      402
# 2            8.0       8.0       9.0     a       95
# 3            4.6      -1.0       1.0     3      389
# 4            4.6      -1.0       1.0     9      402

# %%
for col in data.columns:
    print("missing data in {} : {} i.e. {}%".format(col,len(data[data[col].isnull()]),
                                                       len(data[data[col].isnull()])/float(len(data))*100))
# Out:
# missing data in co2 : 34095 i.e. 8.68149272277278%
# missing data in humi : 17018 i.e. 4.333234877728324%
# missing data in no : 98614 i.e. 25.109744049377188%
# missing data in no2 : 46623 i.e. 11.871454325086827%
# missing data in pm10 : 32425 i.e. 8.256266359756781%
# missing data in pm2.5 : 304035 i.e. 77.41538759255675%
# missing data in station : 0 i.e. 0.0%
# missing data in temp : 17114 i.e. 4.3576790279376265%
# missing data in date : 0 i.e. 0.0%
# missing data in time : 0 i.e. 0.0%
# missing data in precipitation : 538 i.e. 0.13698909179796911%
# missing data in temp_min : 538 i.e. 0.13698909179796911%
# missing data in temp_max : 538 i.e. 0.13698909179796911%
# missing data in ligne : 0 i.e. 0.0%
# missing data in stop_id : 0 i.e. 0.0%

# %% [markdown]
# Top three missing data columns :
# -no
# -pm10
# -pm2.5
# -co2
#
# WARNING no missing data in timetable, stations ect... because I(romain) generated the data

# %% [markdown]
# #### Date & Time processing

# %%
data['year'],data['month'],data['day'] = data["date"].str.split("-").str
data['year'] = data['year'].astype(int)
data['month'] = data['month'].astype(int)
data['day'] = data['day'].astype(int)

# %%
data['hour'],data['minute'],data['second'] = data["time"].str.split(":").str
data['hour'] = data['hour'].astype(int)
data['minute'] = data['minute'].astype(int)
data['second'] = data['second'].astype(int)

# %%
data = data.drop(labels = ['minute','second'], axis = 1)

# %%
data['date'] = pd.to_datetime(data['date'], format = "%Y-%m-%d")

# %%
data['weekday'] = data['date'].dt.dayofweek

# %%
data['time'] = pd.to_datetime(data['time'], format = "%H:%M:%S")

# %%
data['time'] = data["time"].dt.time

# %%
print(len(data[data["co2"].isnull() & 
                        data["humi"].isnull() &
                        data["no"].isnull() & 
                        data["no2"].isnull() &
                        data["pm10"].isnull() & 
                        data["pm2.5"].isnull() &  
                       data["temp"].isnull()]))
# Out:
# 15860

# %% [markdown]
# For 15860 raws, data is missing for almost all sensors (except rain) -> remove all these rows

# %%
missing_data = data[data["co2"].isnull() | 
                        data["humi"].isnull() |
                        data["no"].isnull() | 
                        data["no2"].isnull() |
                        data["pm10"].isnull() | 
                        data["pm2.5"].isnull() | 
                        data["no2"].isnull() |
                       data["temp"].isnull()]

# %%
missing_data.head()
# Out:
#       co2  humi     no   no2   pm10  pm2.5 station  temp       date      time  \
# 0   403.0  51.2    NaN   NaN  295.0  118.0   auber  20.4 2013-01-01  10:00:00
# 1   403.0  51.2    NaN   NaN  295.0  118.0   auber  20.4 2013-01-01  10:00:00
# 2   403.0  51.2    NaN   NaN  295.0  118.0   auber  20.4 2013-01-01  10:00:00
# 15    NaN  44.2  235.0  48.0  654.0  254.0   auber  17.8 2013-01-17  10:00:00
# 16    NaN  44.2  235.0  48.0  654.0  254.0   auber  17.8 2013-01-17  10:00:00
#
#     precipitation  temp_min  temp_max ligne  stop_id  year  month  day  hour  \
# 0             8.0       8.0       9.0     3      389  2013      1    1    10
# 1             8.0       8.0       9.0     9      402  2013      1    1    10
# 2             8.0       8.0       9.0     a       95  2013      1    1    10
# 15            0.0      -7.0       0.0     3      389  2013      1   17    10
# 16            0.0      -7.0       0.0     9      402  2013      1   17    10
#
#     weekday
# 0         1
# 1         1
# 2         1
# 15        3
# 16        3

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.distplot(missing_data[missing_data['station'] == 'auber']['month'], ax = ax, kde = False)

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.distplot(missing_data[missing_data['station'] == 'chatelet']['month'], ax = ax, kde = False)

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.distplot(missing_data[missing_data['station'] == 'franklin']['month'], ax = ax, kde = False)

# %%
fig, ax = plt.subplots(figsize=(20,10))
missing_data.plot(x = 'date', y = ['co2','no','no2','humi','pm10','pm2.5','temp'], ax = ax)
plt.show()
# Out:
# c:\program files\python36\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %% [markdown]
# A chatelet il semble que le mois d'aout contiennent le plus de valeurs manquantes (# vacances), les autres contiennent une quantité constante de données manquantes.

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax = sns.countplot(ax=ax,data = missing_data,x="station")

# %% [markdown]
# Let's choose auber because, it is the station with the least missing data

# %%
data = data.drop(labels=['no','no2','pm10','pm2.5'], axis = 1)

# %%
data = data.dropna()

# %%
data = data[data['station'] == 'auber']

# %%
data['frequentation'] = data['a']+data['b']+data['1']+data['11']+data['14']+data['3']+data['4']+data['7']+data['9']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\program files\python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-6a7740955a8d> in <module>()
# ----> 1 data['frequentation'] = data['a']+data['b']+data['1']+data['11']+data['14']+data['3']+data['4']+data['7']+data['9']
#
# c:\program files\python36\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# c:\program files\python36\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# c:\program files\python36\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# c:\program files\python36\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# c:\program files\python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a'

# %%
fig, ax = plt.subplots(figsize=(15,5))
sns.factorplot(x="month", y="frequentation", hue = "year", data=data, kind = "box", ax = ax)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-eb66c512baa8> in <module>()
#       1 fig, ax = plt.subplots(figsize=(15,5))
# ----> 2 sns.factorplot(x="month", y="frequentation", hue = "year", data=data, kind = "box", ax = ax)
#
# c:\program files\python36\lib\site-packages\seaborn\categorical.py in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, size, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3489     # facets to ensure representation of all data in the final plot
#    3490     p = _CategoricalPlotter()
# -> 3491     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3492     order = p.group_names
#    3493     hue_order = p.hue_names
#
# c:\program files\python36\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     149                 if isinstance(input, string_types):
#     150                     err = "Could not interpret input '{}'".format(input)
# --> 151                     raise ValueError(err)
#     152
#     153             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'frequentation'

# %%
fig, ax = plt.subplots(figsize=(20,10))
data.plot(x = ['date'],y = ['co2', 'frequentation'], ax = ax)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-b8f63d1d31c3> in <module>()
#       1 fig, ax = plt.subplots(figsize=(20,10))
# ----> 2 data.plot(x = ['date'],y = ['co2', 'frequentation'], ax = ax)
#
# c:\program files\python36\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2675                           fontsize=fontsize, colormap=colormap, table=table,
#    2676                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2677                           sort_columns=sort_columns, **kwds)
#    2678     __call__.__doc__ = plot_frame.__doc__
#    2679
#
# c:\program files\python36\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1900                  yerr=yerr, xerr=xerr,
#    1901                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1902                  **kwds)
#    1903
#    1904
#
# c:\program files\python36\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1713                     y = data.columns[y]
#    1714                 label = kwds['label'] if 'label' in kwds else y
# -> 1715                 series = data[y].copy()  # Don't modify
#    1716                 series.name = label
#    1717
#
# c:\program files\python36\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# c:\program files\python36\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# c:\program files\python36\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1267                 if mask.any():
#    1268                     raise KeyError('{mask} not in index'
# -> 1269                                    .format(mask=objarr[mask]))
#    1270
#    1271                 return _values_from_object(indexer)
#
# KeyError: "['frequentation'] not in index"

# %%
data_2013 = data[data['year'] == 2013]

# %%
data_2013_3_17 = data[(data['year'] == 2013) & (data['month'] == 3) & (data['day'] == 17)]

# %%
fig, ax = plt.subplots(figsize=(20,10))
data_2013_3_17.plot(x = 'time',y = 'co2', ax = ax)

# %%
fig, ax = plt.subplots(figsize=(20,10))
data_2013.plot(x = 'date',y = 'co2', ax = ax)

# %%
data_2013['co2_slide'] = data_2013['co2'].rolling(window = 24*7).mean()
# Out:
# c:\users\romain meynard\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
fig, ax = plt.subplots(figsize=(20,10))
data_2013[(data_2013['year'] == 2013) & (data_2013['month'] == 3)].plot(x = ["date","time"],y = "co2_slide", ax = ax, label = "auber")

# %%
data = data[['frequentation','year','month','hour','weekday','precipitation','temp_min','temp_max','co2']]

# %%
sns.pairplot(data)

# %%
corr = data.corr()

# %%
# plot correlation matrix
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
names = ['frequentation', 'year', 'month', 'hour', 'temp', 'weekday', 'precipitation', 'temp_min','temp_max' 'co2']
ax.set_xticklabels(names, rotation = 45)
ax.set_yticklabels(names)
plt.show()

# %% [markdown]
# ## Feature engineering

# %%
import numpy as np

# %%
data['co2_log'] = data['co2'].apply(lambda x:np.log(x))
data['precipitation_log'] = data['precipitation'].apply(lambda x:np.log(x))
# Out:
# c:\users\romain meynard\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# c:\users\romain meynard\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Modelization

# %%
features = ['frequentation','year','month','hour', 'weekday', 'precipitation','temp_min','temp_max',]
X = data[features].values
Y = data['co2'].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn import ensemble

# %%
cv_ratio = 0.8

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y)

# %% [markdown]
# #### Ridge Regression

# %%
clf = linear_model.Lasso(alpha = 0.1)
clf.fit(X_train,Y_train)
clf.score(X_test,Y_test)
# Out:
# 0.40499846174698623

# %%
for idx in range(len(features)):
    print(features[idx],clf.coef_[idx])
# Out:
# frequentation 0.109947660825
# year -0.79656524713
# month 0.0
# hour 4.30362583078
# weekday -10.8389393792
# precipitation -1.1041044193
# temp_min -0.480090097904
# temp_max -0.916943496327

# %% [markdown]
# #### ElasticNet Regression

# %%
clf = linear_model.ElasticNet(alpha = 0.1)
clf.fit(X_train,Y_train)
clf.score(X_test,Y_test)
# Out:
# 0.40499792753180064

# %%
for idx in range(len(features)):
    print(features[idx],clf.coef_[idx])
# Out:
# frequentation 0.110001088577
# year -0.804121010024
# month 0.00134457055423
# hour 4.29874875333
# weekday -10.7176238994
# precipitation -1.10287239202
# temp_min -0.479644495684
# temp_max -0.917825609434

# %% [markdown]
# #### Random Forest Regression

# %%
clf = ensemble.RandomForestRegressor(n_estimators = 100)
clf.fit(X_train,Y_train)
clf.score(X_test,Y_test)
# Out:
# c:\users\romain meynard\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 0.86651898490636681

# %%
for idx in range(len(features)):
    print(features[idx],clf.feature_importances_[idx])
# Out:
# frequentation 0.148022283751
# year 0.0213342726612
# month 0.0435949896079
# hour 0.51111619819
# weekday 0.161284471905
# precipitation 0.0362705357697
# temp_min 0.0347253979621
# temp_max 0.0436518501537
